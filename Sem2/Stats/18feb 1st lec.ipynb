# %%
import pandas as pd

# %%
df = pd.read_excel('24thoct.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c15684ddb058> in <module>
# ----> 1 df = pd.read_excel('24thoct.xlsx')
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# ...

# %%
d1 = {'Customer_id':pd.Series([1,2,3,4,5,6]),
  'Product':pd.Series(['Oven','Oven','Oven','Television',
                       'Television',
                       'Television'])}
df1 = pd.DataFrame(d1)
 
# data frame 2
d2 = {'Customer_id':pd.Series([2,4,6,8]),
    'State':pd.Series(['California','California','Texas','Texas'])}
df2 = pd.DataFrame(d2)

# %%
final = pd.merge(df1,df2,on = 'Customer_id',how='outer')

# %%
final
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            8         NaN       Texas

# %%
#Create a DataFrame
d = {
    'Name':['Alisa','Bobby','Cathrine','Madonna',
            'Rocky','Sebastian','Jaqluine','Rahul','David'],
   'Score1':[62,47,55,74,31,77,85,63,42],
   'Score2':[89,87,67,55,47,72,76,79,44],
   'Score3':[56,86,77,45,73,62,74,89,71]}
 
df1 = pd.DataFrame(d)
df1


# create dataframe - df2
d = {
    'Name':['Andrew','Ajay','Teresa'],
   'Score1':[32,71,57],
   'Score2':[92,99,69],
   'Score3':[67,97,68]}
 
df2 = pd.DataFrame(d)
df2
# Out:
#      Name  Score1  Score2  Score3
# 0  Andrew      32      92      67
# 1    Ajay      71      99      97
# 2  Teresa      57      69      68

# %%
df1.append(df2,ignore_index= True)
# Out:
#          Name  Score1  Score2  Score3
# 0       Alisa      62      89      56
# 1       Bobby      47      87      86
# 2    Cathrine      55      67      77
# 3     Madonna      74      55      45
# 4       Rocky      31      47      73
# 5   Sebastian      77      72      62
# 6    Jaqluine      85      76      74
# 7       Rahul      63      79      89
# 8       David      42      44      71
# 9      Andrew      32      92      67
# 10       Ajay      71      99      97
# 11     Teresa      57      69      68

# %%
df1.append(df2)
# Out:
#         Name  Score1  Score2  Score3
# 0      Alisa      62      89      56
# 1      Bobby      47      87      86
# 2   Cathrine      55      67      77
# 3    Madonna      74      55      45
# 4      Rocky      31      47      73
# 5  Sebastian      77      72      62
# 6   Jaqluine      85      76      74
# 7      Rahul      63      79      89
# 8      David      42      44      71
# 0     Andrew      32      92      67
# 1       Ajay      71      99      97
# 2     Teresa      57      69      68

# %%
sample_dict = {'Name':['Irfan','Eshaan','Vansh'],'Age':[26,19,18],'Marks':[80,90]}

# %%
df = pd.DataFrame(sample_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d6d0b7014d1a> in <module>
# ----> 1 df = pd.DataFrame(sample_dict)
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/.local/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
df
# Out:
#      Name  Age  Marks
# 0   Irfan   26     80
# 1  Eshaan   19     90
# 2   Vansh   18     95

# %%
import seaborn as sns

# %%
#Create a DataFrame
d = {
    'Name':['Alisa','Bobby','Cathrine','Madonna',
            'Rocky','Sebastian','Jaqluine','Rahul','David'],
   'Score1':[62,47,55,74,31,77,85,63,42],
   'Score2':[89,87,67,55,47,72,76,79,44],
   'Score3':[56,86,77,45,73,62,74,89,71]}
 
df1 = pd.DataFrame(d)
df1


# create dataframe - df2
d = {
    'Name':['Andrew','Ajay','Teresa'],
   'Score1':[32,71,57],
   'Score2':[92,99,69],
   'Score3':[67,97,68]}
 
df2 = pd.DataFrame(d)
df2
# Out:
#      Name  Score1  Score2  Score3
# 0  Andrew      32      92      67
# 1    Ajay      71      99      97
# 2  Teresa      57      69      68

# %%
df = df1.append(df2,ignore_index=True)

# %%
df
# Out:
#          Name  Score1  Score2  Score3
# 0       Alisa      62      89      56
# 1       Bobby      47      87      86
# 2    Cathrine      55      67      77
# 3     Madonna      74      55      45
# 4       Rocky      31      47      73
# 5   Sebastian      77      72      62
# 6    Jaqluine      85      76      74
# 7       Rahul      63      79      89
# 8       David      42      44      71
# 9      Andrew      32      92      67
# 10       Ajay      71      99      97
# 11     Teresa      57      69      68

# %%
data = sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x='day',y='size',data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='size'>

# %%
p=sns.barplot(x='sex',y='total_bill',hue='sex',data=data)

# %%
for index,row in data.iterrows():
    p.text(row.name,row.tip,round(row.total_bill,2),color='black')

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(data['total_bill'])
plt.show()
