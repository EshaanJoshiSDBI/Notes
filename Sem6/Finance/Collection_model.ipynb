# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 50000)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('Train_Dataset.csv',low_memory=False)

# %%
df.head()
# Out:
#          ID  Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0  12216081         9000.0        0.0         1.0          0.0        1.0
# 1  12102421        11475.0        0.0         1.0          0.0        1.0
# 2  12141834            NaN        0.0         0.0          0.0        1.0
# 3  12136742         6750.0        0.0         1.0          1.0        1.0
# 4  12148641         9000.0        0.0         1.0          0.0        1.0
#
#    Child_Count Credit_Amount  Loan_Annuity Accompany_Client  \
# 0          0.0         59256       2510.55            Alone
# 1          0.0       31276.8       2288.70            Alone
# 2          NaN         80865       2621.70            Alone
# 3          3.0         26955       2129.40            Alone
# 4          0.0         43200       1564.65            Alone
#
#   Client_Income_Type Client_Education Client_Marital_Status Client_Gender  \
# 0            Retired        Secondary                     M          Male
# ...

# %%
df.ID.nunique()
# Out:
# 121856

# %%
len(df)
# Out:
# 121856

# %%
df.Loan_Contract_Type.value_counts()
# Out:
# CL    107118
# RL     11087
# Name: Loan_Contract_Type, dtype: int64

# %%
df.describe().columns
# Out:
# Index(['ID', 'Client_Income', 'Car_Owned', 'Bike_Owned', 'Active_Loan',
#        'House_Own', 'Child_Count', 'Loan_Annuity',
#        'Population_Region_Relative', 'Age_Days', 'Employed_Days',
#        'Registration_Days', 'ID_Days', 'Own_House_Age', 'Mobile_Tag',
#        'Homephone_Tag', 'Workphone_Working', 'Client_Family_Members',
#        'Cleint_City_Rating', 'Application_Process_Day',
#        'Application_Process_Hour', 'Score_Source_1', 'Score_Source_2',
#        'Score_Source_3', 'Social_Circle_Default', 'Phone_Change',
#        'Credit_Bureau', 'Default'],
#       dtype='object')

# %%
obj_cols = [i for i in df.columns if i not in df.describe().columns.tolist()]

# %%
obj_cols
# Out:
# ['Credit_Amount',
#  'Accompany_Client',
#  'Client_Income_Type',
#  'Client_Education',
#  'Client_Marital_Status',
#  'Client_Gender',
#  'Loan_Contract_Type',
#  'Client_Housing_Type',
#  'Client_Occupation',
#  'Client_Permanent_Match_Tag',
#  'Client_Contact_Work_Tag',
#  'Type_Organization']

# %%
df_na = pd.DataFrame(df.isna().sum(),columns=['Count of Null'])

# %%
df_na['Pct_null'] = round((df_na['Count of Null']/len(df))*100,2)

# %%
df_na.sort_values(by='Count of Null',ascending=False)
# Out:
#                             Count of Null  Pct_null
# Own_House_Age                       80095     65.73
# Score_Source_1                      68835     56.49
# Social_Circle_Default               61928     50.82
# Client_Occupation                   41435     34.00
# Score_Source_3                      26922     22.09
# Credit_Bureau                       18540     15.21
# ID_Days                              5985      4.91
# Score_Source_2                       5686      4.67
# Population_Region_Relative           4868      3.99
# Loan_Annuity                         4826      3.96
# Client_Income_Type                   3701      3.04
# Client_Housing_Type                  3687      3.03
# Employed_Days                        3666      3.01
# Phone_Change                         3664      3.01
# Application_Process_Hour             3663      3.01
# House_Own                            3661      3.00
# Loan_Contract_Type                   3651      3.00
# ...

# %%
df.drop(columns=['Own_House_Age','Score_Source_1','Social_Circle_Default'],inplace=True)
