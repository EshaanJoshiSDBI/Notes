# %%
library(TTR)

# %%
sales = c(5,7,8,9,4,6,7,8,5,7)

# %%
plot(sales)
# Out:
# plot without title

# %%
plot(ts(sales))
# Out:
# plot without title

# %%
mean(sales)
# Out:
# [1] 6.6

# %% [markdown]
# Naive forecasting method

# %%
sales
# Out:
#  [1] 5 7 8 9 4 6 7 8 5 7

# %% [markdown]
# 3 day moving average

# %% [markdown]
# |Value|MVA|
# |-----|:----|
# |5|-|
# |7|-|
# |8|6.6667|
# |9|8|
# |4|7|
# |6|6.333|
# |7|5.6667|
# |8|7|
# |5|6.6667|
# |7|6.6667|
